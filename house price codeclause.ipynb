# %% [markdown]
# *projectid*: #CC69859
#
# *Project Title* : Predicting House Prices
#
# *Project level*: Entry level
#
# *Assinged by* : CodeClause internship
#
# *Assinged to*: Nooren Mariyam
#
# 01-Aug-2025 to 30-Aug-2025

# %% [markdown]
# *AIM*: Build a simple linear regression model to predict house prices based on features like number of bedrooms and square footage
#
# *DESCRIPTION*: use a dataset of house prices  split it into training and testing set  and build a regression model using scikit learn

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  mean_squared_error,r2_score

# %%
#creating synthetic house price  data 
df= pd.DataFrame({
    "Number of Bedrooms": np.random.randint(2,8,30),
    "square of living " : np.random.randint(600,1800,30),
    "square of lot" :np.random.randint(1500,5000,30),
    "price ": np.random.randint(3500000,20000000,30),
})

df
# Out:
#     Number of Bedrooms  square of living   square of lot    price
# 0                    6               1534           4589   7660051
# 1                    2               1289           3053  18523137
# 2                    7                664           3195  11705248
# 3                    7               1772           2977  11398852
# 4                    4               1733           3802   9517957
# 5                    4               1258           4100  12412985
# 6                    4               1099           4303   9200714
# 7                    3               1189           4879   9683931
# 8                    6                706           3498   8297841
# 9                    5               1290           2072   4090821
# 10                   3                609           1911  16920351
# 11                   3                867           3569  13746942
# 12                   3                647           4002   5493147
# ...

# %%
# prepare features and target
X = df[["Number of Bedrooms","square of living ","square of lot"]]
y = df["price "]

# %%
#spliting into traing and testing
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
#train the linear regression model
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predictions and evaluations 
y_pred = model.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
print("mse:",mse)
print("r2:",r2)
# Out:
# mse: 13829174077672.514
# r2: -0.016110694717848206
